# %% [markdown]
# # Classification and Change Detection Task
#
# This notebook implements the task to find Sentinel-2 images within the period 2017-2019 with no cloud cover for a specific area of interest.

# %% [markdown]
# ## Setup and Installation
#
# Install required packages and import necessary libraries.

# %%
# Install required packages
# !pip install rasterio
# !pip install --extra-index-url https://artifactory.vgt.vito.be/api/pypi/python-packages/simple terracatalogueclient
# !pip install pyproj
# !pip install shapely
# !pip install matplotlib
# !pip install numpy
# !pip install scikit-image
# !pip install eodag
# !pip install ipywidgets
# !pip install ipyevents
# !pip install sentinelhub

# %%
# Import required libraries
from terracatalogueclient import Catalogue
import datetime as dt
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from skimage import exposure
from pyproj import Transformer, CRS
from shapely.geometry import Polygon

# Initialize the Terrascope catalogue
catalogue = Catalogue()

# %% [markdown]
# ## Step 1: Find Sentinel-2 Images (2017-2019) with No Cloud Cover
#
# Search for all Sentinel-2 images in the specified area and time period with zero cloud cover.

# %%
# Define the date range for 2017-2019
startDate = dt.date(2017, 1, 1)
endDate = dt.date(2019, 12, 31)

# Define the coordinates from the task (WGS84)
lat = 50.379123
lon = 4.392829

# Define a bounding box (adjust size as needed for "appropriate size")
# (Small because need to download entire file anyway and to ensure the centre coordinate is in it)
bbox = [lon - 0.002, lat - 0.002, lon + 0.002, lat + 0.002]

# Define cloud cover threshold for filtering
cloudcover_threshold = 1

print(f"Searching for products from {startDate} to {endDate}")
print(f"Area of Interest: lat={lat}, lon={lon}")
print(f"Bounding box: {bbox}")

# Get all products in the date range and location
products = list(catalogue.get_products(
    "urn:eop:VITO:TERRASCOPE_S2_TOC_V2",
    start=startDate,
    end=endDate,
    bbox=bbox
))

print(f"\nTotal products found: {len(products)}")

# Filter for images with no cloud cover (cloudCover == 0)
# Note: You may need to adjust this threshold if no images with 0% cloud cover exist
no_cloud_products = [
    product for product in products 
    if product.properties["productInformation"]["cloudCover"] <= cloudcover_threshold
]

# Sort products by cloud cover percentage (ascending)
no_cloud_products.sort(key=lambda p: p.properties["productInformation"]["cloudCover"])

print(f"Products with < {cloudcover_threshold}% cloud cover: {len(no_cloud_products)}")

# Display the cloud-free images
if len(no_cloud_products) > 0:
    print("\nCloud-free products (sorted by cloud cover %):")
    for i, product in enumerate(no_cloud_products, 1):
        print(f"{i}. {product.title}: {product.properties['productInformation']['cloudCover']}% clouds")
else:
    print("\nNo products found.")
# Out:
# Searching for products from 2017-01-01 to 2019-12-31
# Area of Interest: lat=50.379123, lon=4.392829
# Bounding box: [4.390829, 50.377123, 4.394829, 50.381123]
#
# Total products found: 394
# Products with < 1% cloud cover: 49
#
# Cloud-free products (sorted by cloud cover %):
# 1. S2B_20181010T104019_31UER_TOC_V200: 0.007% clouds
# 2. S2B_20171015T104009_31UER_TOC_V200: 0.008% clouds
# 3. S2B_20190227T104019_31UER_TOC_V200: 0.009% clouds
# 4. S2B_20180722T104019_31UER_TOC_V200: 0.01% clouds
# 5. S2B_20180930T104019_31UER_TOC_V200: 0.012% clouds
# 6. S2A_20190920T104021_31UER_TOC_V200: 0.016% clouds
# 7. S2B_20190418T104029_31UER_TOC_V200: 0.016% clouds
# 8. S2A_20180418T104021_31UER_TOC_V200: 0.018% clouds
# 9. S2A_20170327T105021_31UER_TOC_V200: 0.027% clouds
# 10. S2B_20170707T104019_31UER_TOC_V200: 0.028% clouds
# 11. S2B_20170829T105019_31UER_TOC_V200: 0.029% clouds
# 12. S2B_20190401T105029_31UER_TOC_V200: 0.031% clouds
# 13. S2A_20190513T104031_31UER_TOC_V200: 0.034% clouds
# 14. S2B_20180225T105019_31UER_TOC_V200: 0.034% clouds
# 15. S2B_20180702T104019_31UER_TOC_V200: 0.035% clouds
# 16. S2B_20190421T105039_31UER_TOC_V200: 0.035% clouds
# 17. S2B_20190627T104029_31UER_TOC_V200: 0.035% clouds
# 18. S2A_20180508T104031_31UER_TOC_V200: 0.036% clouds
# 19. S2B_20180725T105029_31UER_TOC_V200: 0.037% clouds
# 20. S2A_20180627T104021_31UER_TOC_V200: 0.039% clouds
# 21. S2B_20190329T104029_31UER_TOC_V200: 0.039% clouds
# 22. S2B_20180222T104029_31UER_TOC_V200: 0.041% clouds
# 23. S2A_20190225T105021_31UER_TOC_V200: 0.045% clouds
# 24. S2A_20190215T105131_31UER_TOC_V200: 0.049% clouds
# 25. S2A_20190824T105031_31UER_TOC_V200: 0.05% clouds
# 26. S2A_20180806T104021_31UER_TOC_V200: 0.051% clouds
# 27. S2B_20191204T104319_31UER_TOC_V200: 0.069% clouds
# 28. S2A_20181117T105321_31UER_TOC_V200: 0.075% clouds
# 29. S2B_20180506T105029_31UER_TOC_V200: 0.079% clouds
# 30. S2A_20180630T105031_31UER_TOC_V200: 0.084% clouds
# 31. S2B_20190717T104029_31UER_TOC_V200: 0.087% clouds
# 32. S2A_20170526T105031_31UER_TOC_V200: 0.117% clouds
# 33. S2B_20180801T104019_31UER_TOC_V200: 0.138% clouds
# 34. S2B_20190121T105349_31UER_TOC_V200: 0.144% clouds
# 35. S2A_20190602T104031_31UER_TOC_V200: 0.178% clouds
# 36. S2A_20181104T104211_31UER_TOC_V200: 0.206% clouds
# 37. S2B_20190411T105029_31UER_TOC_V200: 0.254% clouds
# 38. S2A_20180518T104021_31UER_TOC_V200: 0.26% clouds
# 39. S2B_20190322T105029_31UER_TOC_V200: 0.331% clouds
# 40. S2B_20190217T104119_31UER_TOC_V200: 0.373% clouds
# 41. S2B_20181013T105029_31UER_TOC_V200: 0.454% clouds
# 42. S2A_20171119T104331_31UER_TOC_V200: 0.474% clouds
# 43. S2A_20180421T105031_31UER_TOC_V200: 0.505% clouds
# 44. S2B_20190915T104019_31UER_TOC_V200: 0.567% clouds
# 45. S2A_20170126T105321_31UER_TOC_V200: 0.632% clouds
# 46. S2A_20181021T110101_31UER_TOC_V200: 0.842% clouds
# 47. S2B_20171107T105229_31UER_TOC_V200: 0.889% clouds
# 48. S2B_20180406T105029_31UER_TOC_V200: 0.935% clouds
# 49. S2B_20190826T104029_31UER_TOC_V200: 0.983% clouds

# %% [markdown]
# See downloader.py for automatic downloading of the (cropped) files

# %%
# Load and read the downloaded band files with AOI extraction
from pathlib import Path
import rasterio
from rasterio.windows import Window
from pyproj import Transformer, CRS as ProjCRS
import numpy as np

download_dir = Path("sentinel_data_subset")

def load_product_files(product_name, verbose=True):
    # Find files matching this product
    band_files = {
        'B02': None,  # Blue
        'B03': None,  # Green
        'B04': None,  # Red
        'B08': None,  # NIR
        'B11': None,  # SWIR
    }
    
    # Search for band files
    # for file in download_dir.glob(f"urn_eop_VITO_TERRASCOPE_S2_TOC_V2_{product_name.split('_')[0]}_{product_name.split('_')[1]}*"):
    for file in download_dir.glob(f"{product_name.split('_')[0]}_{product_name.split('_')[1]}*"):
        for band in band_files.keys():
            if f"{band}_" in file.name:
                band_files[band] = file
                break
    
    # Check if all required bands are present
    missing = [k for k, v in band_files.items() if v is None]
    if missing:
        print(f"Missing band files: {missing}")
        print("Please download the required bands first.")
    else:
        print("All required bands found:")
        # for band, path in band_files.items():
        #     print(f"  {band}: {path.name}")
        
        # The downloader already extracted the 6x6 km box, so read the entire file
        # No need to define a window - just read all data
        with rasterio.open(band_files['B04']) as dataset:
            if verbose:
                print(f"Image bounds: {dataset.bounds}")
                print(f"Image CRS: {dataset.crs}")
                print(f"Image size: {dataset.width} x {dataset.height} pixels")
                print(f"Pixel resolution: {dataset.res}")
            
            profile = dataset.profile
        
        # Read the entire bands (no window needed - downloader already extracted the area)
        with rasterio.open(band_files['B02']) as src:
            blue = src.read(1).astype(float)
            
        with rasterio.open(band_files['B03']) as src:
            green = src.read(1).astype(float)
            
        with rasterio.open(band_files['B04']) as src:
            red = src.read(1).astype(float)
            
        with rasterio.open(band_files['B08']) as src:
            nir = src.read(1).astype(float)
            
        # For SWIR (20m resolution), read entire band and resample
        with rasterio.open(band_files['B11']) as src:
            swir_20m = src.read(1).astype(float)
            
            # Resample SWIR to 10m to match other bands
            from scipy.ndimage import zoom
            scale_factor = 2.0
            swir = zoom(swir_20m, scale_factor, order=1)
            
            # Ensure same shape as other bands
            if swir.shape != red.shape:
                swir = swir[:red.shape[0], :red.shape[1]]
        
        if verbose: 
            print(f"\nAOI extracted successfully. Shape: {red.shape}")
            # Calculate actual coverage from pixel size
            pixel_size_m = dataset.res[0]  # meters per pixel
            width_km = (red.shape[1] * pixel_size_m) / 1000
            height_km = (red.shape[0] * pixel_size_m) / 1000
            print(f"AOI covers approximately {width_km:.1f} km x {height_km:.1f} km")
        return [blue, green, red, nir, swir]
# Find the downloaded files for the first product
if len(no_cloud_products) > 0:
    product = no_cloud_products[0]
    product_name = product.title
    [blue, green, red, nir, swir] = load_product_files(product_name)
else:
    print("No products available to process.")
# Out:
# All required bands found:
# Image bounds: BoundingBox(left=595960.0, bottom=5578650.0, right=602100.0, top=5584780.0)
# Image CRS: EPSG:32631
# Image size: 614 x 613 pixels
# Pixel resolution: (10.0, 10.0)
#
# AOI extracted successfully. Shape: (613, 614)
# AOI covers approximately 6.1 km x 6.1 km

# %% [markdown]
# # Step 2: Compute the NDVI, NDBI and NDWI for these images.

# %%
# Compute NDVI, NDBI, and NDWI indices
import numpy as np

# Avoid division by zero
def safe_divide(a, b):
    """Safely divide two arrays, returning 0 where denominator is 0."""
    with np.errstate(divide='ignore', invalid='ignore'):
        result = np.where(b != 0, a / b, 0)
    return np.nan_to_num(result, nan=0)

def compute_indices(red, nir, swir, green, verbose=True):
    # Compute NDVI: (NIR - Red) / (NIR + Red)
    ndvi = safe_divide(nir - red, nir + red)

    # Ensure all arrays have the same shape before computing NDBI
    min_rows = min(swir.shape[0], nir.shape[0])
    min_cols = min(swir.shape[1], nir.shape[1])
    swir_crop = swir[:min_rows, :min_cols]
    nir_crop = nir[:min_rows, :min_cols]

    # Compute NDBI: (SWIR - NIR) / (SWIR + NIR)
    ndbi = safe_divide(swir_crop - nir_crop, swir_crop + nir_crop)

    # Compute NDWI: (Green - NIR) / (Green + NIR)
    ndwi = safe_divide(green - nir, green + nir)

    if verbose:
        print("Indices computed successfully!")
        print(f"NDVI range: [{ndvi.min():.3f}, {ndvi.max():.3f}]")
        print(f"NDBI range: [{ndbi.min():.3f}, {ndbi.max():.3f}]")
        print(f"NDWI range: [{ndwi.min():.3f}, {ndwi.max():.3f}]")
    return [ndvi, ndbi, ndwi]

[ndvi, ndbi, ndwi] = compute_indices(red, nir, swir, green)
# Out:
# Indices computed successfully!
# NDVI range: [-0.767, 0.999]
# NDBI range: [-0.697, 0.966]
# NDWI range: [-1.000, 0.746]

# %%
# Visualize the RGB image and computed indices
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# Plot RGB image (True Color Composite)
# Normalize RGB values to 0-1 range for display
rgb = np.stack([red, green, blue], axis=-1)
# Apply percentile stretching for better visualization
p2, p98 = np.percentile(rgb, (2, 98))
rgb_stretched = np.clip((rgb - p2) / (p98 - p2), 0, 1)

axes[0, 0].imshow(rgb_stretched)
axes[0, 0].set_title('RGB - True Color')
axes[0, 0].axis('off')

# Plot NDVI
im1 = axes[0, 1].imshow(ndvi, cmap='RdYlGn', vmin=-1, vmax=1)
axes[0, 1].set_title('NDVI - Vegetation')
axes[0, 1].axis('off')
plt.colorbar(im1, ax=axes[0, 1], label='NDVI', fraction=0.046)

# Plot NDBI
im2 = axes[1, 0].imshow(ndbi, cmap='RdYlBu_r', vmin=-1, vmax=1)
axes[1, 0].set_title('NDBI (Built-up)')
axes[1, 0].axis('off')
plt.colorbar(im2, ax=axes[1, 0], label='NDBI', fraction=0.046)

# Plot NDWI
im3 = axes[1, 1].imshow(ndwi, cmap='Blues', vmin=-1, vmax=1)
axes[1, 1].set_title('NDWI (Water)')
axes[1, 1].axis('off')
plt.colorbar(im3, ax=axes[1, 1], label='NDWI', fraction=0.046)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Step 3: Create class masks (vegetation, built-up, water)
# This step thresholds NDVI, NDBI, and NDWI to create per-class binary masks and makes them mutually exclusive.
#
# - Vegetation: NDVI > 0.3
# - Built-up: NDBI > 0.2
# - Water: NDWI > 0.2
#
# A small morphological clean-up removes speckles, and a simple priority resolves overlaps: Water > Vegetation > Built-up.

# %%
# Create binary masks for vegetation, built-up, and water
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from skimage.morphology import remove_small_objects, disk, binary_opening, binary_closing

# Thresholds 
ndvi_thr = 0.4   # vegetation
ndbi_thr = 0.12   # built-up
ndwi_thr = 0.3  # water

def compute_masks(ndvi, ndbi, ndwi, ndvi_thr=ndvi_thr, ndbi_thr=ndbi_thr, ndwi_thr=ndwi_thr):
    # Calculate dimensions to ensure all arrays match
    min_rows = min(ndvi.shape[0], ndbi.shape[0], ndwi.shape[0])
    min_cols = min(ndvi.shape[1], ndbi.shape[1], ndwi.shape[1])
    
    # Crop all arrays to match dimensions
    ndvi_crop = ndvi[:min_rows, :min_cols]
    ndbi_crop = ndbi[:min_rows, :min_cols]
    ndwi_crop = ndwi[:min_rows, :min_cols]

    # Initial thresholded masks
    veg0 = (ndvi_crop > ndvi_thr)
    built0 = (ndbi_crop > ndbi_thr)
    water0 = (ndwi_crop > ndwi_thr)

    # Simple cleaning to remove small speckles and smooth edges
    def clean(mask: np.ndarray, min_size: int = 5, radius: int = 1) -> np.ndarray:
        mask = mask.astype(bool)
        mask = remove_small_objects(mask, min_size=min_size)
        if radius and radius > 0:
            se = disk(radius)
            mask = binary_opening(mask, se)
            mask = binary_closing(mask, se)
        return mask

    # Enforce mutual exclusivity with priority: Water > Vegetation > Built-up
    water_mask = clean(water0, radius=1)
    veg_mask = clean(veg0 & ~water_mask, radius=1)
    built_mask = clean(built0 & ~water_mask & ~veg_mask, radius=1)
    return veg_mask, built_mask, water_mask, ndvi_crop, veg0, built0, water0
[veg_mask, built_mask, water_mask, ndvi_crop, veg0, built0, water0] = compute_masks(ndvi, ndbi, ndwi)

# Get mask dimensions for visualization
min_rows, min_cols = ndvi_crop.shape

# Report coverage
total_px = int(ndvi_crop.size)
get_pct = lambda m: 100.0 * float(m.sum()) / total_px if total_px > 0 else 0.0
print(f"Pixels: total={total_px}")
print(f"  Vegetation: {get_pct(veg0):.1f}% → {get_pct(veg_mask):.1f}% ({veg_mask.sum()} px)")
print(f"  Built-up:   {get_pct(built0):.1f}% → {get_pct(built_mask):.1f}% ({built_mask.sum()} px)")
print(f"  Water:      {get_pct(water0):.1f}% → {get_pct(water_mask):.1f}% ({water_mask.sum()} px)")

# Visualization: RGB + combined classification mask
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# RGB (crop to match mask dimensions)
rgb_crop = np.stack([red[:min_rows, :min_cols], green[:min_rows, :min_cols], blue[:min_rows, :min_cols]], axis=-1)
p2, p98 = np.percentile(rgb_crop, (2, 98))
rgb_stretched = np.clip((rgb_crop - p2) / (p98 - p2), 0, 1)
axes[0].imshow(rgb_stretched)
axes[0].set_title('RGB - True Color')
axes[0].axis('off')

# Combined classification mask: 0=unclassified, 1=vegetation, 2=built-up, 3=water
classification = np.zeros_like(veg_mask, dtype=np.uint8)
classification[veg_mask] = 1
classification[built_mask] = 2
classification[water_mask] = 3

# Custom colormap: black, green, orange, blue
from matplotlib.colors import ListedColormap
colors = ['black', 'green', 'orange', 'blue']
cmap = ListedColormap(colors)

im = axes[1].imshow(classification, cmap=cmap, vmin=0, vmax=3)
axes[1].set_title('Classification Mask')
axes[1].axis('off')

# Add colorbar with labels
cbar = plt.colorbar(im, ax=axes[1], ticks=[0, 1, 2, 3], fraction=0.046)
cbar.ax.set_yticklabels(['Unclassified', 'Vegetation', 'Built-up', 'Water'])

plt.tight_layout()
plt.show()
# Out:
# Pixels: total=376382
#   Vegetation: 76.2% → 76.1% (286493 px)
#   Built-up:   13.9% → 3.9% (14617 px)
#   Water:      0.4% → 0.2% (808 px)

# %% [markdown]
# # Step 4: Detecting changes

# %%
MIN_PCT_CHANGE = 1  # Minimum percentage change to consider significant

# Sort products by date
no_cloud_products_sorted = sorted(no_cloud_products, key=lambda p: p.properties['date'])

print(f"Processing {len(no_cloud_products_sorted)} products sorted by date\n")

# Track previous masks for change detection
prev_classification = None
prev_rgb = None
prev_date = None
use_verbose = False

# Change detection options
ignore_unclassified = False  # Set to False to include changes to/from Unclassified

# Store change visualizations for carousel
change_plots = []

for idx, product in enumerate(no_cloud_products_sorted):
    product_name = product.title
    product_date = product.properties['date'].split('T')[0]
    
    print(f"\n{'='*60}")
    print(f"[{idx+1}/{len(no_cloud_products_sorted)}] {product_name}")
    print(f"Date: {product_date}")
    print('='*60)
    
    try:
        # Load and process product
        [blue, green, red, nir, swir] = load_product_files(product_name, verbose=use_verbose)
        [ndvi, ndbi, ndwi] = compute_indices(red, nir, swir, green, verbose=use_verbose)
        [veg_mask, built_mask, water_mask, ndvi_crop, veg0, built0, water0] = compute_masks(ndvi, ndbi, ndwi)
        
        # Create classification map
        classification = np.zeros_like(veg_mask, dtype=np.uint8)
        classification[veg_mask] = 1
        classification[built_mask] = 2
        classification[water_mask] = 3
        
        # Calculate coverage
        total_px = int(classification.size)
        get_pct = lambda val: 100.0 * float((classification == val).sum()) / total_px
        
        print(f"\nCoverage:")
        print(f"  Vegetation: {get_pct(1):.1f}%")
        print(f"  Built-up:   {get_pct(2):.1f}%")
        print(f"  Water:      {get_pct(3):.1f}%")
        print(f"  Unclassified: {get_pct(0):.1f}%")
        
        # Prepare RGB crop (stretched) matching mask dimensions
        min_rows, min_cols = classification.shape
        rgb_crop = np.stack([
            red[:min_rows, :min_cols],
            green[:min_rows, :min_cols],
            blue[:min_rows, :min_cols]
        ], axis=-1)
        p2, p98 = np.percentile(rgb_crop, (2, 98))
        rgb_stretched = np.clip((rgb_crop - p2) / (p98 - p2 + 1e-12), 0, 1)
        
        # Detect changes from previous date
        if prev_classification is not None:
            # Calculate pixel-wise changes
            if ignore_unclassified:
                # Only count changes between classified pixels (exclude unclassified transitions)
                classified_mask = (prev_classification > 0) & (classification > 0)
                changed_pixels = ((classification != prev_classification) & classified_mask).sum()
            else:
                changed_pixels = (classification != prev_classification).sum()
            
            change_pct = 100.0 * changed_pixels / total_px
            
            # Also calculate classified-only change percentage for carousel filtering
            classified_mask_check = (prev_classification > 0) & (classification > 0)
            changed_pixels_classified = ((classification != prev_classification) & classified_mask_check).sum()
            change_pct_classified = 100.0 * changed_pixels_classified / total_px
            
            if change_pct > 0.5:  # Report if more than 0.5% changed
                print(f"\n⚠️ CHANGE DETECTED from {prev_date} to {product_date}:")
                print(f"   {change_pct:.1f}% of pixels changed ({changed_pixels:,} pixels)")
                if ignore_unclassified:
                    print(f"   (excluding changes to/from Unclassified)")
                
                # Detailed change breakdown
                change_summary = []
                for from_class in range(4):
                    for to_class in range(4):
                        if from_class != to_class:
                            # Skip changes involving unclassified if option is set
                            if ignore_unclassified and (from_class == 0 or to_class == 0):
                                continue
                            
                            mask = (prev_classification == from_class) & (classification == to_class)
                            count = mask.sum()
                            if count > 0:
                                class_names = ['Unclassified', 'Vegetation', 'Built-up', 'Water']
                                pct = 100.0 * count / total_px
                                print(f"   {class_names[from_class]} → {class_names[to_class]}: {pct:.2f}% ({count:,} px)")
                                change_summary.append(f"{class_names[from_class]} → {class_names[to_class]}: {pct:.2f}%")
                
                # Create change visualization
                if ignore_unclassified:
                    # Only show changes between classified pixels
                    classified_mask = (prev_classification > 0) & (classification > 0)
                    change_mask = ((classification != prev_classification) & classified_mask).astype(np.uint8)
                else:
                    change_mask = (classification != prev_classification).astype(np.uint8)
                
                # Store plot data with RGB images (only if classified change > 1%)
                if change_pct_classified > MIN_PCT_CHANGE:
                    change_plots.append({
                        'prev_date': prev_date,
                        'curr_date': product_date,
                        'prev_class': prev_classification.copy(),
                        'curr_class': classification.copy(),
                        'change_mask': change_mask,
                        'change_pct': change_pct,
                        'summary': change_summary,
                        'prev_rgb': prev_rgb.copy() if prev_rgb is not None else None,
                        'curr_rgb': rgb_stretched.copy()
                    })
                else:
                    print(f"   (Change < 1% when excluding unclassified, not added to carousel)")
            else:
                print(f"\nNo significant change from {prev_date} (only {change_pct:.2f}% changed)")
        
        # Store for next iteration
        prev_classification = classification.copy()
        prev_rgb = rgb_stretched.copy()
        prev_date = product_date
        
    except Exception as e:
        print(f"✗ Error processing product: {e}")
        continue

print(f"\n{'='*60}")
print("Change detection complete!")
print(f"Found {len(change_plots)} significant changes")
print('='*60)
# Out:
# Processing 49 products sorted by date
#
#
# ============================================================
# [1/49] S2A_20170126T105321_31UER_TOC_V200
# Date: 2017-01-26
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 64.9%
#   Built-up:   5.5%
#   Water:      0.1%
#   Unclassified: 29.5%
#
# ============================================================
# [2/49] S2A_20170327T105021_31UER_TOC_V200
# Date: 2017-03-27
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 73.4%
#   Built-up:   2.6%
#   Water:      0.2%
#   Unclassified: 23.8%
#
# ⚠️ CHANGE DETECTED from 2017-01-26 to 2017-03-27:
#    21.6% of pixels changed (81,240 pixels)
#    Unclassified → Vegetation: 12.60% (47,409 px)
#    Unclassified → Built-up: 0.57% (2,154 px)
#    Unclassified → Water: 0.13% (503 px)
#    Vegetation → Unclassified: 3.88% (14,586 px)
#    Vegetation → Built-up: 0.41% (1,544 px)
#    Vegetation → Water: 0.00% (7 px)
#    Built-up → Unclassified: 3.73% (14,025 px)
#    Built-up → Vegetation: 0.17% (652 px)
#    Built-up → Water: 0.03% (107 px)
#    Water → Unclassified: 0.04% (147 px)
#    Water → Built-up: 0.03% (106 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [3/49] S2A_20170526T105031_31UER_TOC_V200
# Date: 2017-05-26
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 78.6%
#   Built-up:   2.2%
#   Water:      0.2%
#   Unclassified: 19.0%
#
# ⚠️ CHANGE DETECTED from 2017-03-27 to 2017-05-26:
#    10.0% of pixels changed (37,667 pixels)
#    Unclassified → Vegetation: 6.17% (23,228 px)
#    Unclassified → Built-up: 0.95% (3,574 px)
#    Unclassified → Water: 0.01% (53 px)
#    Vegetation → Unclassified: 1.51% (5,680 px)
#    Vegetation → Built-up: 0.03% (96 px)
#    Built-up → Unclassified: 0.74% (2,784 px)
#    Built-up → Vegetation: 0.57% (2,143 px)
#    Built-up → Water: 0.00% (4 px)
#    Water → Unclassified: 0.02% (86 px)
#    Water → Vegetation: 0.00% (3 px)
#    Water → Built-up: 0.00% (16 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [4/49] S2B_20170707T104019_31UER_TOC_V200
# Date: 2017-07-07
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 76.2%
#   Built-up:   3.6%
#   Water:      0.2%
#   Unclassified: 20.0%
#
# ⚠️ CHANGE DETECTED from 2017-05-26 to 2017-07-07:
#    12.7% of pixels changed (47,849 pixels)
#    Unclassified → Vegetation: 3.99% (15,024 px)
#    Unclassified → Built-up: 1.51% (5,674 px)
#    Unclassified → Water: 0.03% (131 px)
#    Vegetation → Unclassified: 6.18% (23,243 px)
#    Vegetation → Built-up: 0.40% (1,521 px)
#    Vegetation → Water: 0.01% (34 px)
#    Built-up → Unclassified: 0.37% (1,391 px)
#    Built-up → Vegetation: 0.21% (788 px)
#    Built-up → Water: 0.01% (32 px)
#    Water → Unclassified: 0.00% (11 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [5/49] S2B_20170829T105019_31UER_TOC_V200
# Date: 2017-08-29
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 78.2%
#   Built-up:   4.8%
#   Water:      0.1%
#   Unclassified: 16.9%
#
# ⚠️ CHANGE DETECTED from 2017-07-07 to 2017-08-29:
#    13.0% of pixels changed (48,987 pixels)
#    Unclassified → Vegetation: 5.15% (19,397 px)
#    Unclassified → Built-up: 2.40% (9,036 px)
#    Unclassified → Water: 0.00% (10 px)
#    Vegetation → Unclassified: 2.93% (11,043 px)
#    Vegetation → Built-up: 0.61% (2,308 px)
#    Built-up → Unclassified: 1.42% (5,329 px)
#    Built-up → Vegetation: 0.41% (1,533 px)
#    Water → Unclassified: 0.08% (305 px)
#    Water → Vegetation: 0.00% (14 px)
#    Water → Built-up: 0.00% (12 px)
#
# ============================================================
# [6/49] S2B_20171015T104009_31UER_TOC_V200
# Date: 2017-10-15
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 78.0%
#   Built-up:   3.2%
#   Water:      0.1%
#   Unclassified: 18.6%
#
# ⚠️ CHANGE DETECTED from 2017-08-29 to 2017-10-15:
#    13.1% of pixels changed (49,128 pixels)
#    Unclassified → Vegetation: 3.61% (13,602 px)
#    Unclassified → Built-up: 0.87% (3,265 px)
#    Unclassified → Water: 0.04% (145 px)
#    Vegetation → Unclassified: 4.20% (15,821 px)
#    Vegetation → Built-up: 0.95% (3,562 px)
#    Built-up → Unclassified: 2.01% (7,562 px)
#    Built-up → Vegetation: 1.34% (5,031 px)
#    Built-up → Water: 0.00% (4 px)
#    Water → Unclassified: 0.04% (134 px)
#    Water → Built-up: 0.00% (2 px)
#
# ============================================================
# [7/49] S2B_20171107T105229_31UER_TOC_V200
# Date: 2017-11-07
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 82.6%
#   Built-up:   1.9%
#   Water:      0.1%
#   Unclassified: 15.4%
#
# ⚠️ CHANGE DETECTED from 2017-10-15 to 2017-11-07:
#    9.4% of pixels changed (35,339 pixels)
#    Unclassified → Vegetation: 5.17% (19,470 px)
#    Unclassified → Built-up: 0.61% (2,295 px)
#    Unclassified → Water: 0.01% (20 px)
#    Vegetation → Unclassified: 1.52% (5,725 px)
#    Vegetation → Built-up: 0.06% (233 px)
#    Vegetation → Water: 0.00% (1 px)
#    Built-up → Unclassified: 1.01% (3,808 px)
#    Built-up → Vegetation: 0.98% (3,670 px)
#    Built-up → Water: 0.00% (5 px)
#    Water → Unclassified: 0.02% (59 px)
#    Water → Vegetation: 0.01% (47 px)
#    Water → Built-up: 0.00% (6 px)
#
# ============================================================
# [8/49] S2A_20171119T104331_31UER_TOC_V200
# Date: 2017-11-19
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 80.8%
#   Built-up:   2.0%
#   Water:      0.0%
#   Unclassified: 17.1%
#
# ⚠️ CHANGE DETECTED from 2017-11-07 to 2017-11-19:
#    7.1% of pixels changed (26,878 pixels)
#    Unclassified → Vegetation: 1.80% (6,758 px)
#    Unclassified → Built-up: 0.75% (2,837 px)
#    Unclassified → Water: 0.00% (10 px)
#    Vegetation → Unclassified: 3.50% (13,172 px)
#    Vegetation → Built-up: 0.16% (602 px)
#    Built-up → Unclassified: 0.79% (2,990 px)
#    Built-up → Vegetation: 0.07% (253 px)
#    Built-up → Water: 0.00% (2 px)
#    Water → Unclassified: 0.04% (168 px)
#    Water → Vegetation: 0.00% (1 px)
#    Water → Built-up: 0.02% (85 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [9/49] S2B_20180222T104029_31UER_TOC_V200
# Date: 2018-02-22
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 73.4%
#   Built-up:   2.3%
#   Water:      0.1%
#   Unclassified: 24.2%
#
# ⚠️ CHANGE DETECTED from 2017-11-19 to 2018-02-22:
#    12.3% of pixels changed (46,245 pixels)
#    Unclassified → Vegetation: 1.47% (5,514 px)
#    Unclassified → Built-up: 0.84% (3,176 px)
#    Unclassified → Water: 0.05% (170 px)
#    Vegetation → Unclassified: 8.41% (31,664 px)
#    Vegetation → Built-up: 0.49% (1,826 px)
#    Vegetation → Water: 0.00% (8 px)
#    Built-up → Unclassified: 0.97% (3,650 px)
#    Built-up → Vegetation: 0.01% (34 px)
#    Built-up → Water: 0.04% (134 px)
#    Water → Unclassified: 0.01% (52 px)
#    Water → Built-up: 0.00% (17 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [10/49] S2B_20180225T105019_31UER_TOC_V200
# Date: 2018-02-25
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 74.1%
#   Built-up:   4.2%
#   Water:      0.2%
#   Unclassified: 21.5%
#
# ⚠️ CHANGE DETECTED from 2018-02-22 to 2018-02-25:
#    6.9% of pixels changed (25,795 pixels)
#    Unclassified → Vegetation: 2.38% (8,958 px)
#    Unclassified → Built-up: 2.18% (8,206 px)
#    Unclassified → Water: 0.07% (257 px)
#    Vegetation → Unclassified: 1.61% (6,063 px)
#    Vegetation → Built-up: 0.14% (524 px)
#    Built-up → Unclassified: 0.35% (1,318 px)
#    Built-up → Vegetation: 0.10% (395 px)
#    Built-up → Water: 0.02% (61 px)
#    Water → Unclassified: 0.00% (7 px)
#    Water → Built-up: 0.00% (6 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [11/49] S2B_20180406T105029_31UER_TOC_V200
# Date: 2018-04-06
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 72.4%
#   Built-up:   1.5%
#   Water:      0.1%
#   Unclassified: 26.0%
#
# ⚠️ CHANGE DETECTED from 2018-02-25 to 2018-04-06:
#    9.6% of pixels changed (36,253 pixels)
#    Unclassified → Vegetation: 2.26% (8,512 px)
#    Unclassified → Built-up: 0.18% (679 px)
#    Unclassified → Water: 0.01% (25 px)
#    Vegetation → Unclassified: 3.96% (14,891 px)
#    Vegetation → Built-up: 0.10% (378 px)
#    Built-up → Unclassified: 2.92% (10,995 px)
#    Built-up → Vegetation: 0.07% (269 px)
#    Water → Unclassified: 0.10% (387 px)
#    Water → Built-up: 0.03% (117 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [12/49] S2A_20180418T104021_31UER_TOC_V200
# Date: 2018-04-18
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 76.2%
#   Built-up:   2.5%
#   Water:      0.1%
#   Unclassified: 21.2%
#
# ⚠️ CHANGE DETECTED from 2018-04-06 to 2018-04-18:
#    10.2% of pixels changed (38,478 pixels)
#    Unclassified → Vegetation: 6.00% (22,580 px)
#    Unclassified → Built-up: 1.40% (5,271 px)
#    Unclassified → Water: 0.04% (168 px)
#    Vegetation → Unclassified: 2.26% (8,502 px)
#    Vegetation → Built-up: 0.05% (176 px)
#    Built-up → Unclassified: 0.31% (1,153 px)
#    Built-up → Vegetation: 0.14% (540 px)
#    Built-up → Water: 0.02% (88 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [13/49] S2A_20180421T105031_31UER_TOC_V200
# Date: 2018-04-21
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 77.0%
#   Built-up:   0.2%
#   Water:      0.0%
#   Unclassified: 22.7%
#
# ⚠️ CHANGE DETECTED from 2018-04-18 to 2018-04-21:
#    6.0% of pixels changed (22,406 pixels)
#    Unclassified → Vegetation: 2.16% (8,128 px)
#    Unclassified → Built-up: 0.00% (5 px)
#    Vegetation → Unclassified: 1.43% (5,384 px)
#    Vegetation → Built-up: 0.00% (1 px)
#    Built-up → Unclassified: 2.17% (8,174 px)
#    Built-up → Vegetation: 0.05% (207 px)
#    Water → Unclassified: 0.13% (507 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [14/49] S2B_20180506T105029_31UER_TOC_V200
# Date: 2018-05-06
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 80.4%
#   Built-up:   2.0%
#   Water:      0.2%
#   Unclassified: 17.4%
#
# ⚠️ CHANGE DETECTED from 2018-04-21 to 2018-05-06:
#    7.7% of pixels changed (28,906 pixels)
#    Unclassified → Vegetation: 4.49% (16,912 px)
#    Unclassified → Built-up: 1.82% (6,839 px)
#    Unclassified → Water: 0.20% (751 px)
#    Vegetation → Unclassified: 1.14% (4,289 px)
#    Vegetation → Built-up: 0.01% (25 px)
#    Built-up → Unclassified: 0.01% (33 px)
#    Built-up → Vegetation: 0.02% (57 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [15/49] S2A_20180508T104031_31UER_TOC_V200
# Date: 2018-05-08
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 79.9%
#   Built-up:   1.7%
#   Water:      0.2%
#   Unclassified: 18.3%
#
# ⚠️ CHANGE DETECTED from 2018-05-06 to 2018-05-08:
#    6.1% of pixels changed (22,987 pixels)
#    Unclassified → Vegetation: 2.15% (8,089 px)
#    Unclassified → Built-up: 0.39% (1,480 px)
#    Unclassified → Water: 0.01% (34 px)
#    Vegetation → Unclassified: 2.64% (9,951 px)
#    Vegetation → Built-up: 0.06% (241 px)
#    Vegetation → Water: 0.00% (3 px)
#    Built-up → Unclassified: 0.77% (2,897 px)
#    Built-up → Vegetation: 0.06% (224 px)
#    Built-up → Water: 0.00% (4 px)
#    Water → Unclassified: 0.01% (44 px)
#    Water → Vegetation: 0.00% (15 px)
#    Water → Built-up: 0.00% (5 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [16/49] S2A_20180518T104021_31UER_TOC_V200
# Date: 2018-05-18
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 81.1%
#   Built-up:   0.3%
#   Water:      0.1%
#   Unclassified: 18.6%
#
# ⚠️ CHANGE DETECTED from 2018-05-08 to 2018-05-18:
#    5.7% of pixels changed (21,470 pixels)
#    Unclassified → Vegetation: 2.61% (9,833 px)
#    Unclassified → Built-up: 0.02% (88 px)
#    Vegetation → Unclassified: 1.52% (5,703 px)
#    Vegetation → Built-up: 0.00% (3 px)
#    Built-up → Unclassified: 1.33% (5,024 px)
#    Built-up → Vegetation: 0.08% (303 px)
#    Water → Unclassified: 0.13% (494 px)
#    Water → Vegetation: 0.00% (9 px)
#    Water → Built-up: 0.00% (13 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [17/49] S2A_20180627T104021_31UER_TOC_V200
# Date: 2018-06-27
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 79.3%
#   Built-up:   2.9%
#   Water:      0.2%
#   Unclassified: 17.6%
#
# ⚠️ CHANGE DETECTED from 2018-05-18 to 2018-06-27:
#    10.1% of pixels changed (38,056 pixels)
#    Unclassified → Vegetation: 2.80% (10,525 px)
#    Unclassified → Built-up: 2.50% (9,420 px)
#    Unclassified → Water: 0.17% (643 px)
#    Vegetation → Unclassified: 4.42% (16,652 px)
#    Vegetation → Built-up: 0.17% (638 px)
#    Vegetation → Water: 0.01% (30 px)
#    Built-up → Unclassified: 0.01% (47 px)
#    Built-up → Vegetation: 0.02% (68 px)
#    Built-up → Water: 0.01% (33 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [18/49] S2A_20180630T105031_31UER_TOC_V200
# Date: 2018-06-30
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 77.2%
#   Built-up:   3.9%
#   Water:      0.3%
#   Unclassified: 18.7%
#
# ⚠️ CHANGE DETECTED from 2018-06-27 to 2018-06-30:
#    5.4% of pixels changed (20,241 pixels)
#    Unclassified → Vegetation: 0.76% (2,864 px)
#    Unclassified → Built-up: 1.31% (4,921 px)
#    Unclassified → Water: 0.01% (50 px)
#    Vegetation → Unclassified: 2.88% (10,823 px)
#    Vegetation → Built-up: 0.04% (137 px)
#    Vegetation → Water: 0.00% (13 px)
#    Built-up → Unclassified: 0.31% (1,169 px)
#    Built-up → Vegetation: 0.05% (197 px)
#    Built-up → Water: 0.01% (52 px)
#    Water → Unclassified: 0.00% (11 px)
#    Water → Vegetation: 0.00% (2 px)
#    Water → Built-up: 0.00% (2 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [19/49] S2B_20180702T104019_31UER_TOC_V200
# Date: 2018-07-02
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 76.8%
#   Built-up:   2.1%
#   Water:      0.2%
#   Unclassified: 21.0%
#
# ⚠️ CHANGE DETECTED from 2018-06-30 to 2018-07-02:
#    7.8% of pixels changed (29,390 pixels)
#    Unclassified → Vegetation: 2.40% (9,018 px)
#    Unclassified → Built-up: 0.29% (1,085 px)
#    Unclassified → Water: 0.00% (9 px)
#    Vegetation → Unclassified: 2.87% (10,793 px)
#    Vegetation → Built-up: 0.03% (129 px)
#    Vegetation → Water: 0.00% (8 px)
#    Built-up → Unclassified: 2.07% (7,799 px)
#    Built-up → Vegetation: 0.08% (283 px)
#    Water → Unclassified: 0.03% (111 px)
#    Water → Vegetation: 0.01% (29 px)
#    Water → Built-up: 0.03% (126 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [20/49] S2B_20180722T104019_31UER_TOC_V200
# Date: 2018-07-22
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 68.8%
#   Built-up:   5.1%
#   Water:      0.2%
#   Unclassified: 26.0%
#
# ⚠️ CHANGE DETECTED from 2018-07-02 to 2018-07-22:
#    13.4% of pixels changed (50,418 pixels)
#    Unclassified → Vegetation: 1.31% (4,928 px)
#    Unclassified → Built-up: 2.22% (8,369 px)
#    Unclassified → Water: 0.00% (3 px)
#    Vegetation → Unclassified: 7.98% (30,054 px)
#    Vegetation → Built-up: 1.32% (4,977 px)
#    Built-up → Unclassified: 0.53% (1,998 px)
#    Built-up → Vegetation: 0.01% (41 px)
#    Water → Unclassified: 0.01% (47 px)
#    Water → Built-up: 0.00% (1 px)
#
# ============================================================
# [21/49] S2B_20180725T105029_31UER_TOC_V200
# Date: 2018-07-25
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 64.2%
#   Built-up:   7.0%
#   Water:      0.2%
#   Unclassified: 28.6%
#
# ⚠️ CHANGE DETECTED from 2018-07-22 to 2018-07-25:
#    8.4% of pixels changed (31,646 pixels)
#    Unclassified → Vegetation: 0.66% (2,476 px)
#    Unclassified → Built-up: 1.96% (7,391 px)
#    Unclassified → Water: 0.01% (23 px)
#    Vegetation → Unclassified: 4.73% (17,799 px)
#    Vegetation → Built-up: 0.49% (1,844 px)
#    Built-up → Unclassified: 0.54% (2,038 px)
#    Built-up → Vegetation: 0.01% (43 px)
#    Water → Unclassified: 0.01% (32 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [22/49] S2B_20180801T104019_31UER_TOC_V200
# Date: 2018-08-01
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 67.1%
#   Built-up:   6.8%
#   Water:      0.1%
#   Unclassified: 26.0%
#
# ⚠️ CHANGE DETECTED from 2018-07-25 to 2018-08-01:
#    9.5% of pixels changed (35,800 pixels)
#    Unclassified → Vegetation: 3.56% (13,416 px)
#    Unclassified → Built-up: 2.12% (7,962 px)
#    Unclassified → Water: 0.01% (22 px)
#    Vegetation → Unclassified: 1.37% (5,171 px)
#    Vegetation → Built-up: 0.03% (111 px)
#    Built-up → Unclassified: 1.67% (6,287 px)
#    Built-up → Vegetation: 0.69% (2,583 px)
#    Water → Unclassified: 0.06% (239 px)
#    Water → Vegetation: 0.00% (8 px)
#    Water → Built-up: 0.00% (1 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [23/49] S2A_20180806T104021_31UER_TOC_V200
# Date: 2018-08-06
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 66.7%
#   Built-up:   6.8%
#   Water:      0.2%
#   Unclassified: 26.4%
#
# ⚠️ CHANGE DETECTED from 2018-08-01 to 2018-08-06:
#    10.9% of pixels changed (40,961 pixels)
#    Unclassified → Vegetation: 3.40% (12,805 px)
#    Unclassified → Built-up: 1.65% (6,193 px)
#    Unclassified → Water: 0.06% (241 px)
#    Vegetation → Unclassified: 3.61% (13,598 px)
#    Vegetation → Built-up: 0.25% (930 px)
#    Vegetation → Water: 0.00% (14 px)
#    Built-up → Unclassified: 1.82% (6,862 px)
#    Built-up → Vegetation: 0.08% (289 px)
#    Built-up → Water: 0.00% (5 px)
#    Water → Unclassified: 0.01% (22 px)
#    Water → Built-up: 0.00% (2 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [24/49] S2B_20180930T104019_31UER_TOC_V200
# Date: 2018-09-30
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 77.3%
#   Built-up:   3.2%
#   Water:      0.2%
#   Unclassified: 19.3%
#
# ⚠️ CHANGE DETECTED from 2018-08-06 to 2018-09-30:
#    18.4% of pixels changed (69,153 pixels)
#    Unclassified → Vegetation: 10.60% (39,884 px)
#    Unclassified → Built-up: 0.92% (3,464 px)
#    Unclassified → Water: 0.01% (20 px)
#    Vegetation → Unclassified: 1.98% (7,447 px)
#    Vegetation → Built-up: 0.19% (708 px)
#    Vegetation → Water: 0.00% (13 px)
#    Built-up → Unclassified: 2.47% (9,313 px)
#    Built-up → Vegetation: 2.18% (8,216 px)
#    Built-up → Water: 0.01% (29 px)
#    Water → Unclassified: 0.01% (47 px)
#    Water → Vegetation: 0.00% (12 px)
#
# ============================================================
# [25/49] S2B_20181010T104019_31UER_TOC_V200
# Date: 2018-10-10
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 76.6%
#   Built-up:   3.8%
#   Water:      0.2%
#   Unclassified: 19.4%
#
# ⚠️ CHANGE DETECTED from 2018-09-30 to 2018-10-10:
#    4.6% of pixels changed (17,295 pixels)
#    Unclassified → Vegetation: 1.15% (4,345 px)
#    Unclassified → Built-up: 1.07% (4,010 px)
#    Vegetation → Unclassified: 1.77% (6,679 px)
#    Vegetation → Built-up: 0.05% (186 px)
#    Built-up → Unclassified: 0.51% (1,905 px)
#    Built-up → Vegetation: 0.02% (59 px)
#    Water → Unclassified: 0.03% (100 px)
#    Water → Built-up: 0.00% (11 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [26/49] S2B_20181013T105029_31UER_TOC_V200
# Date: 2018-10-13
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 76.1%
#   Built-up:   3.9%
#   Water:      0.1%
#   Unclassified: 19.8%
#
# ⚠️ CHANGE DETECTED from 2018-10-10 to 2018-10-13:
#    5.2% of pixels changed (19,683 pixels)
#    Unclassified → Vegetation: 1.26% (4,749 px)
#    Unclassified → Built-up: 1.11% (4,176 px)
#    Unclassified → Water: 0.00% (2 px)
#    Vegetation → Unclassified: 1.80% (6,760 px)
#    Vegetation → Built-up: 0.03% (127 px)
#    Built-up → Unclassified: 0.96% (3,616 px)
#    Built-up → Vegetation: 0.04% (165 px)
#    Water → Unclassified: 0.02% (81 px)
#    Water → Built-up: 0.00% (7 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [27/49] S2A_20181021T110101_31UER_TOC_V200
# Date: 2018-10-21
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 0.0%
#   Built-up:   0.0%
#   Water:      0.0%
#   Unclassified: 100.0%
#
# ⚠️ CHANGE DETECTED from 2018-10-13 to 2018-10-21:
#    80.2% of pixels changed (301,886 pixels)
#    Vegetation → Unclassified: 76.12% (286,518 px)
#    Built-up → Unclassified: 3.94% (14,837 px)
#    Water → Unclassified: 0.14% (531 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [28/49] S2A_20181104T104211_31UER_TOC_V200
# Date: 2018-11-04
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 74.8%
#   Built-up:   0.9%
#   Water:      0.0%
#   Unclassified: 24.3%
#
# ⚠️ CHANGE DETECTED from 2018-10-21 to 2018-11-04:
#    75.7% of pixels changed (284,805 pixels)
#    Unclassified → Vegetation: 74.77% (281,417 px)
#    Unclassified → Built-up: 0.86% (3,249 px)
#    Unclassified → Water: 0.04% (139 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [29/49] S2A_20181117T105321_31UER_TOC_V200
# Date: 2018-11-17
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 78.7%
#   Built-up:   1.9%
#   Water:      0.1%
#   Unclassified: 19.3%
#
# ⚠️ CHANGE DETECTED from 2018-11-04 to 2018-11-17:
#    8.3% of pixels changed (31,332 pixels)
#    Unclassified → Vegetation: 5.28% (19,885 px)
#    Unclassified → Built-up: 1.31% (4,949 px)
#    Unclassified → Water: 0.03% (108 px)
#    Vegetation → Unclassified: 1.32% (4,977 px)
#    Vegetation → Built-up: 0.05% (170 px)
#    Built-up → Unclassified: 0.24% (901 px)
#    Built-up → Vegetation: 0.06% (216 px)
#    Built-up → Water: 0.02% (88 px)
#    Water → Unclassified: 0.01% (28 px)
#    Water → Built-up: 0.00% (10 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [30/49] S2B_20190121T105349_31UER_TOC_V200
# Date: 2019-01-21
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 74.2%
#   Built-up:   2.5%
#   Water:      0.2%
#   Unclassified: 23.1%
#
# ⚠️ CHANGE DETECTED from 2018-11-17 to 2019-01-21:
#    13.2% of pixels changed (49,865 pixels)
#    Unclassified → Vegetation: 3.21% (12,067 px)
#    Unclassified → Built-up: 1.25% (4,719 px)
#    Unclassified → Water: 0.06% (227 px)
#    Vegetation → Unclassified: 7.55% (28,417 px)
#    Vegetation → Built-up: 0.24% (913 px)
#    Vegetation → Water: 0.01% (40 px)
#    Built-up → Unclassified: 0.79% (2,963 px)
#    Built-up → Vegetation: 0.10% (370 px)
#    Built-up → Water: 0.02% (90 px)
#    Water → Unclassified: 0.01% (35 px)
#    Water → Vegetation: 0.00% (1 px)
#    Water → Built-up: 0.01% (23 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [31/49] S2A_20190215T105131_31UER_TOC_V200
# Date: 2019-02-15
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 74.3%
#   Built-up:   3.4%
#   Water:      0.2%
#   Unclassified: 22.0%
#
# ⚠️ CHANGE DETECTED from 2019-01-21 to 2019-02-15:
#    12.7% of pixels changed (47,980 pixels)
#    Unclassified → Vegetation: 4.85% (18,270 px)
#    Unclassified → Built-up: 1.65% (6,204 px)
#    Unclassified → Water: 0.04% (136 px)
#    Vegetation → Unclassified: 4.64% (17,449 px)
#    Vegetation → Built-up: 0.40% (1,500 px)
#    Vegetation → Water: 0.01% (54 px)
#    Built-up → Unclassified: 0.82% (3,071 px)
#    Built-up → Vegetation: 0.24% (920 px)
#    Built-up → Water: 0.07% (250 px)
#    Water → Unclassified: 0.01% (31 px)
#    Water → Vegetation: 0.02% (71 px)
#    Water → Built-up: 0.01% (24 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [32/49] S2B_20190217T104119_31UER_TOC_V200
# Date: 2019-02-17
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 68.7%
#   Built-up:   3.2%
#   Water:      0.1%
#   Unclassified: 28.0%
#
# ⚠️ CHANGE DETECTED from 2019-02-15 to 2019-02-17:
#    9.8% of pixels changed (36,736 pixels)
#    Unclassified → Vegetation: 0.83% (3,112 px)
#    Unclassified → Built-up: 0.72% (2,709 px)
#    Unclassified → Water: 0.00% (4 px)
#    Vegetation → Unclassified: 5.97% (22,474 px)
#    Vegetation → Built-up: 0.51% (1,923 px)
#    Built-up → Unclassified: 1.54% (5,780 px)
#    Built-up → Vegetation: 0.02% (83 px)
#    Built-up → Water: 0.00% (3 px)
#    Water → Unclassified: 0.06% (236 px)
#    Water → Built-up: 0.11% (412 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [33/49] S2A_20190225T105021_31UER_TOC_V200
# Date: 2019-02-25
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 70.2%
#   Built-up:   4.8%
#   Water:      0.2%
#   Unclassified: 24.8%
#
# ⚠️ CHANGE DETECTED from 2019-02-17 to 2019-02-25:
#    9.4% of pixels changed (35,534 pixels)
#    Unclassified → Vegetation: 3.76% (14,164 px)
#    Unclassified → Built-up: 2.35% (8,850 px)
#    Unclassified → Water: 0.04% (146 px)
#    Vegetation → Unclassified: 2.25% (8,485 px)
#    Vegetation → Built-up: 0.13% (484 px)
#    Built-up → Unclassified: 0.66% (2,473 px)
#    Built-up → Vegetation: 0.17% (655 px)
#    Built-up → Water: 0.07% (258 px)
#    Water → Unclassified: 0.00% (9 px)
#    Water → Built-up: 0.00% (10 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [34/49] S2B_20190227T104019_31UER_TOC_V200
# Date: 2019-02-27
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 69.5%
#   Built-up:   5.4%
#   Water:      0.2%
#   Unclassified: 24.8%
#
# ⚠️ CHANGE DETECTED from 2019-02-25 to 2019-02-27:
#    9.6% of pixels changed (36,073 pixels)
#    Unclassified → Vegetation: 2.67% (10,047 px)
#    Unclassified → Built-up: 1.86% (6,991 px)
#    Unclassified → Water: 0.03% (128 px)
#    Vegetation → Unclassified: 3.27% (12,291 px)
#    Vegetation → Built-up: 0.27% (1,006 px)
#    Vegetation → Water: 0.00% (9 px)
#    Built-up → Unclassified: 1.29% (4,856 px)
#    Built-up → Vegetation: 0.15% (566 px)
#    Built-up → Water: 0.03% (128 px)
#    Water → Unclassified: 0.01% (33 px)
#    Water → Built-up: 0.00% (18 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [35/49] S2B_20190322T105029_31UER_TOC_V200
# Date: 2019-03-22
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 73.3%
#   Built-up:   2.3%
#   Water:      0.1%
#   Unclassified: 24.3%
#
# ⚠️ CHANGE DETECTED from 2019-02-27 to 2019-03-22:
#    10.0% of pixels changed (37,819 pixels)
#    Unclassified → Vegetation: 4.79% (18,038 px)
#    Unclassified → Built-up: 0.31% (1,182 px)
#    Unclassified → Water: 0.00% (1 px)
#    Vegetation → Unclassified: 1.24% (4,680 px)
#    Vegetation → Built-up: 0.04% (159 px)
#    Built-up → Unclassified: 3.22% (12,119 px)
#    Built-up → Vegetation: 0.29% (1,084 px)
#    Built-up → Water: 0.00% (3 px)
#    Water → Unclassified: 0.10% (369 px)
#    Water → Built-up: 0.05% (184 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [36/49] S2B_20190329T104029_31UER_TOC_V200
# Date: 2019-03-29
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 73.5%
#   Built-up:   3.6%
#   Water:      0.2%
#   Unclassified: 22.7%
#
# ⚠️ CHANGE DETECTED from 2019-03-22 to 2019-03-29:
#    5.8% of pixels changed (21,957 pixels)
#    Unclassified → Vegetation: 1.91% (7,174 px)
#    Unclassified → Built-up: 1.65% (6,229 px)
#    Unclassified → Water: 0.09% (330 px)
#    Vegetation → Unclassified: 1.68% (6,312 px)
#    Vegetation → Built-up: 0.05% (178 px)
#    Built-up → Unclassified: 0.36% (1,367 px)
#    Built-up → Vegetation: 0.05% (175 px)
#    Built-up → Water: 0.04% (158 px)
#    Water → Unclassified: 0.00% (5 px)
#    Water → Built-up: 0.01% (29 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [37/49] S2B_20190401T105029_31UER_TOC_V200
# Date: 2019-04-01
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 72.0%
#   Built-up:   2.6%
#   Water:      0.2%
#   Unclassified: 25.2%
#
# ⚠️ CHANGE DETECTED from 2019-03-29 to 2019-04-01:
#    5.0% of pixels changed (18,790 pixels)
#    Unclassified → Vegetation: 0.81% (3,045 px)
#    Unclassified → Built-up: 0.35% (1,320 px)
#    Unclassified → Water: 0.00% (5 px)
#    Vegetation → Unclassified: 2.28% (8,587 px)
#    Vegetation → Built-up: 0.06% (213 px)
#    Built-up → Unclassified: 1.44% (5,416 px)
#    Built-up → Vegetation: 0.02% (72 px)
#    Built-up → Water: 0.00% (1 px)
#    Water → Unclassified: 0.03% (108 px)
#    Water → Built-up: 0.01% (23 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [38/49] S2B_20190411T105029_31UER_TOC_V200
# Date: 2019-04-11
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 77.3%
#   Built-up:   1.3%
#   Water:      0.2%
#   Unclassified: 21.3%
#
# ⚠️ CHANGE DETECTED from 2019-04-01 to 2019-04-11:
#    7.2% of pixels changed (27,225 pixels)
#    Unclassified → Vegetation: 5.35% (20,137 px)
#    Unclassified → Built-up: 0.15% (556 px)
#    Unclassified → Water: 0.01% (42 px)
#    Vegetation → Unclassified: 0.32% (1,216 px)
#    Built-up → Unclassified: 1.19% (4,489 px)
#    Built-up → Vegetation: 0.20% (756 px)
#    Built-up → Water: 0.00% (9 px)
#    Water → Unclassified: 0.01% (19 px)
#    Water → Built-up: 0.00% (1 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [39/49] S2B_20190418T104029_31UER_TOC_V200
# Date: 2019-04-18
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 76.2%
#   Built-up:   1.9%
#   Water:      0.2%
#   Unclassified: 21.6%
#
# ⚠️ CHANGE DETECTED from 2019-04-11 to 2019-04-18:
#    6.3% of pixels changed (23,641 pixels)
#    Unclassified → Vegetation: 1.99% (7,492 px)
#    Unclassified → Built-up: 0.89% (3,363 px)
#    Unclassified → Water: 0.02% (77 px)
#    Vegetation → Unclassified: 2.96% (11,151 px)
#    Vegetation → Built-up: 0.06% (237 px)
#    Built-up → Unclassified: 0.32% (1,210 px)
#    Built-up → Vegetation: 0.02% (93 px)
#    Built-up → Water: 0.00% (9 px)
#    Water → Unclassified: 0.00% (9 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [40/49] S2B_20190421T105039_31UER_TOC_V200
# Date: 2019-04-21
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 77.4%
#   Built-up:   1.8%
#   Water:      0.2%
#   Unclassified: 20.6%
#
# ⚠️ CHANGE DETECTED from 2019-04-18 to 2019-04-21:
#    3.6% of pixels changed (13,600 pixels)
#    Unclassified → Vegetation: 1.84% (6,915 px)
#    Unclassified → Built-up: 0.46% (1,717 px)
#    Unclassified → Water: 0.00% (11 px)
#    Vegetation → Unclassified: 0.70% (2,651 px)
#    Vegetation → Built-up: 0.01% (24 px)
#    Built-up → Unclassified: 0.56% (2,114 px)
#    Built-up → Vegetation: 0.04% (143 px)
#    Built-up → Water: 0.00% (1 px)
#    Water → Unclassified: 0.00% (18 px)
#    Water → Built-up: 0.00% (6 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [41/49] S2A_20190513T104031_31UER_TOC_V200
# Date: 2019-05-13
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 80.7%
#   Built-up:   0.9%
#   Water:      0.2%
#   Unclassified: 18.2%
#
# ⚠️ CHANGE DETECTED from 2019-04-21 to 2019-05-13:
#    6.2% of pixels changed (23,307 pixels)
#    Unclassified → Vegetation: 4.06% (15,290 px)
#    Unclassified → Built-up: 0.18% (671 px)
#    Unclassified → Water: 0.01% (20 px)
#    Vegetation → Unclassified: 0.90% (3,387 px)
#    Vegetation → Built-up: 0.00% (9 px)
#    Built-up → Unclassified: 0.94% (3,530 px)
#    Built-up → Vegetation: 0.10% (366 px)
#    Built-up → Water: 0.00% (1 px)
#    Water → Unclassified: 0.00% (11 px)
#    Water → Vegetation: 0.00% (17 px)
#    Water → Built-up: 0.00% (5 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [42/49] S2A_20190602T104031_31UER_TOC_V200
# Date: 2019-06-02
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 79.9%
#   Built-up:   1.7%
#   Water:      0.2%
#   Unclassified: 18.2%
#
# ⚠️ CHANGE DETECTED from 2019-05-13 to 2019-06-02:
#    5.4% of pixels changed (20,221 pixels)
#    Unclassified → Vegetation: 1.73% (6,530 px)
#    Unclassified → Built-up: 0.90% (3,389 px)
#    Unclassified → Water: 0.00% (6 px)
#    Vegetation → Unclassified: 2.52% (9,483 px)
#    Vegetation → Built-up: 0.04% (151 px)
#    Built-up → Unclassified: 0.14% (527 px)
#    Built-up → Vegetation: 0.02% (57 px)
#    Water → Unclassified: 0.01% (55 px)
#    Water → Vegetation: 0.00% (4 px)
#    Water → Built-up: 0.01% (19 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [43/49] S2B_20190627T104029_31UER_TOC_V200
# Date: 2019-06-27
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 78.5%
#   Built-up:   2.8%
#   Water:      0.2%
#   Unclassified: 18.5%
#
# ⚠️ CHANGE DETECTED from 2019-06-02 to 2019-06-27:
#    10.8% of pixels changed (40,700 pixels)
#    Unclassified → Vegetation: 3.85% (14,486 px)
#    Unclassified → Built-up: 1.33% (4,999 px)
#    Unclassified → Water: 0.02% (85 px)
#    Vegetation → Unclassified: 5.11% (19,237 px)
#    Vegetation → Built-up: 0.14% (530 px)
#    Vegetation → Water: 0.01% (20 px)
#    Built-up → Unclassified: 0.30% (1,129 px)
#    Built-up → Vegetation: 0.05% (181 px)
#    Built-up → Water: 0.01% (32 px)
#    Water → Unclassified: 0.00% (1 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [44/49] S2B_20190717T104029_31UER_TOC_V200
# Date: 2019-07-17
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 76.0%
#   Built-up:   1.0%
#   Water:      0.1%
#   Unclassified: 22.9%
#
# ⚠️ CHANGE DETECTED from 2019-06-27 to 2019-07-17:
#    11.1% of pixels changed (41,777 pixels)
#    Unclassified → Vegetation: 3.14% (11,823 px)
#    Unclassified → Built-up: 0.18% (659 px)
#    Vegetation → Unclassified: 5.64% (21,229 px)
#    Vegetation → Built-up: 0.02% (83 px)
#    Built-up → Unclassified: 1.96% (7,367 px)
#    Built-up → Vegetation: 0.04% (133 px)
#    Water → Unclassified: 0.12% (462 px)
#    Water → Vegetation: 0.00% (5 px)
#    Water → Built-up: 0.00% (16 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [45/49] S2A_20190824T105031_31UER_TOC_V200
# Date: 2019-08-24
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 76.8%
#   Built-up:   4.0%
#   Water:      0.2%
#   Unclassified: 19.1%
#
# ⚠️ CHANGE DETECTED from 2019-07-17 to 2019-08-24:
#    11.6% of pixels changed (43,631 pixels)
#    Unclassified → Vegetation: 4.61% (17,370 px)
#    Unclassified → Built-up: 2.66% (9,994 px)
#    Unclassified → Water: 0.06% (243 px)
#    Vegetation → Unclassified: 3.20% (12,044 px)
#    Vegetation → Built-up: 0.68% (2,547 px)
#    Vegetation → Water: 0.00% (5 px)
#    Built-up → Unclassified: 0.34% (1,293 px)
#    Built-up → Vegetation: 0.03% (109 px)
#    Built-up → Water: 0.00% (16 px)
#    Water → Unclassified: 0.00% (10 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [46/49] S2B_20190826T104029_31UER_TOC_V200
# Date: 2019-08-26
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 75.2%
#   Built-up:   4.4%
#   Water:      0.1%
#   Unclassified: 20.3%
#
# ⚠️ CHANGE DETECTED from 2019-08-24 to 2019-08-26:
#    8.1% of pixels changed (30,586 pixels)
#    Unclassified → Vegetation: 2.09% (7,884 px)
#    Unclassified → Built-up: 1.26% (4,734 px)
#    Vegetation → Unclassified: 3.59% (13,502 px)
#    Vegetation → Built-up: 0.14% (525 px)
#    Built-up → Unclassified: 0.93% (3,501 px)
#    Built-up → Vegetation: 0.04% (143 px)
#    Water → Unclassified: 0.07% (265 px)
#    Water → Vegetation: 0.00% (3 px)
#    Water → Built-up: 0.01% (29 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [47/49] S2B_20190915T104019_31UER_TOC_V200
# Date: 2019-09-15
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 76.0%
#   Built-up:   1.4%
#   Water:      0.1%
#   Unclassified: 22.5%
#
# ⚠️ CHANGE DETECTED from 2019-08-26 to 2019-09-15:
#    8.4% of pixels changed (31,583 pixels)
#    Unclassified → Vegetation: 2.81% (10,570 px)
#    Unclassified → Built-up: 0.14% (511 px)
#    Unclassified → Water: 0.00% (1 px)
#    Vegetation → Unclassified: 2.15% (8,100 px)
#    Vegetation → Built-up: 0.05% (202 px)
#    Built-up → Unclassified: 3.00% (11,275 px)
#    Built-up → Vegetation: 0.24% (888 px)
#    Water → Unclassified: 0.01% (36 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [48/49] S2A_20190920T104021_31UER_TOC_V200
# Date: 2019-09-20
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 76.3%
#   Built-up:   3.6%
#   Water:      0.2%
#   Unclassified: 19.9%
#
# ⚠️ CHANGE DETECTED from 2019-09-15 to 2019-09-20:
#    7.1% of pixels changed (26,824 pixels)
#    Unclassified → Vegetation: 2.42% (9,096 px)
#    Unclassified → Built-up: 2.28% (8,583 px)
#    Unclassified → Water: 0.11% (419 px)
#    Vegetation → Unclassified: 2.13% (8,004 px)
#    Vegetation → Built-up: 0.07% (251 px)
#    Vegetation → Water: 0.00% (1 px)
#    Built-up → Unclassified: 0.10% (381 px)
#    Built-up → Vegetation: 0.02% (69 px)
#    Built-up → Water: 0.01% (20 px)
#    (Change < 1% when excluding unclassified, not added to carousel)
#
# ============================================================
# [49/49] S2B_20191204T104319_31UER_TOC_V200
# Date: 2019-12-04
# ============================================================
# All required bands found:
#
# Coverage:
#   Vegetation: 76.1%
#   Built-up:   3.9%
#   Water:      0.2%
#   Unclassified: 19.8%
#
# ⚠️ CHANGE DETECTED from 2019-09-20 to 2019-12-04:
#    14.2% of pixels changed (53,564 pixels)
#    Unclassified → Vegetation: 4.08% (15,351 px)
#    Unclassified → Built-up: 2.35% (8,828 px)
#    Unclassified → Water: 0.04% (161 px)
#    Vegetation → Unclassified: 4.95% (18,642 px)
#    Vegetation → Built-up: 0.34% (1,294 px)
#    Vegetation → Water: 0.00% (18 px)
#    Built-up → Unclassified: 1.34% (5,047 px)
#    Built-up → Vegetation: 1.07% (4,014 px)
#    Built-up → Water: 0.02% (82 px)
#    Water → Unclassified: 0.02% (73 px)
#    Water → Built-up: 0.01% (54 px)
#
# ============================================================
# Change detection complete!
# Found 6 significant changes
# ============================================================

# %%
# Visualize changes in a carousel
if len(change_plots) > 0:
    from matplotlib.colors import ListedColormap
    import ipywidgets as widgets
    from IPython.display import display
    
    # Custom colormap for classification
    colors = ['black', 'green', 'orange', 'blue']
    cmap_class = ListedColormap(colors)
    
    # Change colormap: gray for no change, red for change
    cmap_change = ListedColormap(['lightgray', 'red'])
    
    def plot_change(index, show_unclassified):
        """Plot a specific change comparison with RGB images beneath."""
        if index < 0 or index >= len(change_plots):
            return
        
        data = change_plots[index]
        
        # Recompute change mask based on toggle
        if not show_unclassified:
            # Only show changes between classified pixels
            classified_mask = (data['prev_class'] > 0) & (data['curr_class'] > 0)
            change_mask_display = ((data['curr_class'] != data['prev_class']) & classified_mask).astype(np.uint8)
            changed_pixels = change_mask_display.sum()
        else:
            # Show all changes
            change_mask_display = (data['curr_class'] != data['prev_class']).astype(np.uint8)
            changed_pixels = change_mask_display.sum()
        
        total_px = data['prev_class'].size
        change_pct_display = 100.0 * changed_pixels / total_px
        
        # Create 2-row figure: classifications on top, RGB images beneath
        fig, axes = plt.subplots(2, 3, figsize=(18, 10))
        
        # ===== TOP ROW: Classifications =====
        
        # Previous classification
        im1 = axes[0, 0].imshow(data['prev_class'], cmap=cmap_class, vmin=0, vmax=3)
        axes[0, 0].set_title(f'Classification: {data["prev_date"]}', fontsize=20)
        axes[0, 0].axis('off')
        cbar1 = plt.colorbar(im1, ax=axes[0, 0], ticks=[0, 1, 2, 3], fraction=0.046)
        cbar1.ax.set_yticklabels(['Unclassified', 'Vegetation', 'Built-up', 'Water'], fontsize=16)
        
        # Current classification
        im2 = axes[0, 1].imshow(data['curr_class'], cmap=cmap_class, vmin=0, vmax=3)
        axes[0, 1].set_title(f'Classification: {data["curr_date"]}', fontsize=20)
        axes[0, 1].axis('off')
        cbar2 = plt.colorbar(im2, ax=axes[0, 1], ticks=[0, 1, 2, 3], fraction=0.046)
        cbar2.ax.set_yticklabels(['Unclassified', 'Vegetation', 'Built-up', 'Water'], fontsize=16)
        
        # Change mask (use dynamically computed mask)
        im3 = axes[0, 2].imshow(change_mask_display, cmap=cmap_change, vmin=0, vmax=1)
        title_suffix = "" if show_unclassified else " (classified only)"
        axes[0, 2].set_title(f'Changes: {change_pct_display:.1f}% of pixels{title_suffix}', fontsize=20)
        axes[0, 2].axis('off')
        cbar3 = plt.colorbar(im3, ax=axes[0, 2], ticks=[0, 1], fraction=0.046)
        cbar3.ax.set_yticklabels(['No change', 'Changed'], fontsize=16)
        
        # ===== BOTTOM ROW: RGB images =====
        
        # Previous RGB
        if data.get('prev_rgb') is not None:
            axes[1, 0].imshow(data['prev_rgb'])
            axes[1, 0].set_title(f'RGB: {data["prev_date"]}', fontsize=20)
        else:
            axes[1, 0].text(0.5, 0.5, 'RGB not available', ha='center', va='center', 
                           transform=axes[1, 0].transAxes, fontsize=14)
            axes[1, 0].set_title(f'RGB: {data["prev_date"]}', fontsize=20)
        axes[1, 0].axis('off')
        
        # Current RGB
        axes[1, 1].imshow(data['curr_rgb'])
        axes[1, 1].set_title(f'RGB: {data["curr_date"]}', fontsize=20)
        axes[1, 1].axis('off')
        
        # Add change summary text in bottom-right panel
        axes[1, 2].axis('off')
        if data['summary']:
            # Sort summary by percentage (extract percentage from string and sort descending)
            sorted_summary = sorted(data['summary'], 
                                   key=lambda x: float(x.split(':')[1].strip().rstrip('%')), 
                                   reverse=True)
            summary_text = '\n'.join(sorted_summary[:5])  # Show top 5 changes
            axes[1, 2].text(0.5, 0.5, summary_text, ha='center', va='center',
                           transform=axes[1, 2].transAxes, fontsize=25,
                           bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
        
        plt.tight_layout(rect=(0, 0.04, 1, 1))
        plt.show()
    
    # Create interactive carousel
    print(f"\n🎠 Change Visualization Carousel ({len(change_plots)} changes detected)")
    print("Use the slider to navigate through detected changes:\n")
    
    slider = widgets.IntSlider(
        value=0,
        min=0,
        max=len(change_plots) - 1,
        step=1,
        description='Change:',
        continuous_update=False,
        orientation='horizontal',
        readout=True,
        readout_format='d'
    )
    
    toggle = widgets.Checkbox(
        value=False,
        description='Include Unclassified',
        disabled=False,
        indent=False
    )
    
    # Display the interactive widget with controls side by side
    controls = widgets.HBox([slider, toggle])
    ui = widgets.interactive(plot_change, index=slider, show_unclassified=toggle)
    display(widgets.VBox([controls, ui.children[-1]]))

else:
    print("No significant changes detected to visualize.")
# Out:
# 🎠 Change Visualization Carousel (6 changes detected)
# Use the slider to navigate through detected changes:
# VBox(children=(HBox(children=(IntSlider(value=0, continuous_update=False, description='Change:', max=5), Check…
